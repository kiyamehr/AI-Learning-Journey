# %%
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import tensorflow as tf
from tensorflow.keras.layers import Dense
import numpy as np

# %%
data = load_wine()
X = data['data']
y = data['target']
X.shape, y.shape, X.std()
# Out:
# ((178, 13), (178,), np.float64(215.74620420485243))

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
pca.fit(X_scaled)
# Out:
# PCA(n_components=2)

# %%
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [0.36198848 0.1920749 ]
# [28.94203422 21.08225141]

# %%
X_pca = pca.transform(X_scaled)
X_pca.shape
# Out:
# (178, 2)

# %%
plt.scatter(
    X_pca[:, 0], X_pca[:, 1],
    marker='x',
    c=y,
    cmap='viridis'
            
    )
plt.title('PCA Plot')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %%
x_train, x_cv, y_train, y_cv = train_test_split(X_scaled, y, test_size=0.2)

# %%
tf.random.set_seed(1234)
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(X_scaled.shape[1],)),
    Dense(32, activation='relu', name='L1'),
    Dense(16, activation='relu', name='L2'),
    Dense(3, activation='linear', name='L3'),
])

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(0.001),
    loss = tf.keras.losses.SparseCategoricalCrossentropy(),
)

early_stopping= tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    
)

model.fit(
    x_train, y_train,
    validation_data=[x_cv, y_cv],
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 7.7206 - val_loss: 6.6683
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6430 - val_loss: 5.6901
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.9345 - val_loss: 5.1660
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0928 - val_loss: 4.7323
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6773 - val_loss: 4.2656
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1232 - val_loss: 3.8715
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3398 - val_loss: 3.5032
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1461 - val_loss: 3.0640
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7991 - val_loss: 2.7722
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4645 - val_loss: 2.4421
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4277 - val_loss: 2.1440
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3287 - val_loss: 2.0860
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1903 - val_loss: 1.8451
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0415 - val_loss: 1.8384
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6102 - val_loss: 1.7131
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3759 - val_loss: 1.4915
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2112 - val_loss: 1.4760
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1369 - val_loss: 1.4915
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1334 - val_loss: 1.4791
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1356 - val_loss: 1.4650
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0475 - val_loss: 1.4321
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9805 - val_loss: 1.1677
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9853 - val_loss: 1.1682
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9824 - val_loss: 1.1685
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9867 - val_loss: 1.1684
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.9895 - val_loss: 1.1681
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9159 - val_loss: 1.1679
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9147 - val_loss: 1.1680
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9137 - val_loss: 1.1682
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9130 - val_loss: 1.1684
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9123 - val_loss: 1.1686
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9116 - val_loss: 1.1680

# %%
pred_train = model.predict(x_train)
pred_train = tf.nn.softmax(pred_train)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
